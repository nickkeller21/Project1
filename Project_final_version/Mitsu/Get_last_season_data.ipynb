# %%
import pandas as pd
import matplotlib as plt
import os 
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder

# %% [markdown]
# ## Extract data for given team

# %% [markdown]
# Code to extract all data for a given team
# User need to set the city name in "city".
#
# Raw data are save in ***_raw.csv
# last season in ***_2018-2019.csv

# %%
# set city to search
city = 'oklahoma'
#city = 'houston'

# set output files
dir_name ="DATA/"
base_filename = city
filename_suffix =".csv"
raw_out = os.path.join(dir_name, base_filename + "_rawData" + filename_suffix)
season_out = os.path.join(dir_name, base_filename + "_2018-2019_league_Data" + filename_suffix)

# %%
# Find teams by city.
team_info = teams.find_teams_by_city(city)
team_info
# Out:
# [{'id': 1610612760,
#   'full_name': 'Oklahoma City Thunder',
#   'abbreviation': 'OKC',
#   'nickname': 'Thunder',
#   'city': 'Oklahoma City',
#   'state': 'Oklahoma',
#   'year_founded': 1967}]

# %%
# get abbreviation
abb = team_info[0]["abbreviation"]
abb
# Out:
# 'OKC'

# %%
nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
tmp = [team for team in nba_teams if team['abbreviation'] == abb][0]
team_id = tmp['id']
team_id
# Out:
# 1610612760

# %%
# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=team_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22019  1610612760               OKC  Oklahoma City Thunder  1521900067
# 1     22019  1610612760               OKC  Oklahoma City Thunder  1521900061
# 2     22019  1610612760               OKC  Oklahoma City Thunder  1521900040
# 3     22019  1610612760               OKC  Oklahoma City Thunder  1521900030
# 4     22019  1610612760               OKC  Oklahoma City Thunder  1521900011
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2019-07-12  OKC vs. CRO  W  199   69  ...   0.500     1    24   25   18
# 1  2019-07-11  OKC vs. POR  W  199   92  ...   0.727     9    31   40   17
# 2  2019-07-09  OKC vs. CRO  W  199   84  ...   0.667     6    19   25   20
# 3  2019-07-08    OKC @ PHI  W  211   84  ...   0.720    14    31   45   22
# 4  2019-07-06    OKC @ UTA  L  201   66  ...   0.625     6    35   41   11
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    7    8   13  11         3.4
# 1    7    4   15  20         6.0
# 2   10    6   11  16         0.6
# 3   14    7   19  26         0.2
# 4   10    8   21  17       -10.4
#
# [5 rows x 28 columns]

# %%
# drop NA 
games=games.dropna()
#games_dropNA.count()

# count total matches
total_matches = games["WL"].count()
total_matches
# Out:
# 2109

# %%
games.to_csv(raw_out,index=False)

# %% [markdown]
# ## Extract seasonal data for given city

# %%
# extract data for last season
start_season = "2018-10-1"
end_season   = "2019-06-15"


mask = (games["GAME_DATE"]<end_season) & (games["GAME_DATE"]>start_season)
tmp = games.loc[mask]

# %%
tmp
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 5      42018  1610612760               OKC  Oklahoma City Thunder  0041800165
# 6      42018  1610612760               OKC  Oklahoma City Thunder  0041800164
# 7      42018  1610612760               OKC  Oklahoma City Thunder  0041800163
# 8      42018  1610612760               OKC  Oklahoma City Thunder  0041800162
# 9      42018  1610612760               OKC  Oklahoma City Thunder  0041800161
# 10     22018  1610612760               OKC  Oklahoma City Thunder  0021801226
AME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 5   2019-04-23    OKC @ POR  L  239  115  ...   0.600     6    33   39   24
# 6   2019-04-21  OKC vs. POR  L  241   98  ...   0.773     6    38   44   23
# 7   2019-04-19  OKC vs. POR  W  239  120  ...   0.795     8    29   37   27
# 8   2019-04-16    OKC @ POR  L  240   94  ...   0.679    13    34   47   21
# 9   2019-04-14    OKC @ POR  L  240   99  ...   0.870    18    31   49   18
# 10  2019-04-10    OKC @ MIL  W  240  127  ...   0.615     9    44   53   40
# 11  2019-04-09  OKC vs. HOU  W  240  112  ...   0.800    18    38   56   20
# 12  2019-04-07    OKC @ MIN  W  239  132  ...   0.846    14    32   46   27
# 13  2019-04-05  OKC vs. DET  W  240  123  ...   0.682    21    38   59   30
# 14  2019-04-02  OKC vs. LAL  W  241  119  ...   0.600    17    33   50   33
# 15  2019-03-31  OKC vs. DAL  L  241  103  ...   0.727    15    34   49   19
# 16  2019-03-29  OKC vs. DEN  L  239  105  ...   0.688    11    24   35   19
# 17  2019-03-27  OKC vs. IND  W  240  107  ...   0.632     9    35   44   29
# 18  2019-03-25    OKC @ MEM  L  241  103  ...   0.750    12    29   41   17
# 19  2019-03-22    OKC @ TOR  W  240  116  ...   0.857    12    27   39   30
# 20  2019-03-20  OKC vs. TOR  L  265  114  ...   0.517    16    32   48   22
# 21  2019-03-18  OKC vs. MIA  L  241  107  ...   0.778    13    36   49   21
# 22  2019-03-16  OKC vs. GSW  L  239   88  ...   0.565    17    35   52   18
# 23  2019-03-14    OKC @ IND  L  240  106  ...   0.800     8    36   44   24
# 24  2019-03-13  OKC vs. BKN  W  240  108  ...   0.789    16    35   51   21
# 25  2019-03-11    OKC @ UTA  W  240   98  ...   0.704     6    42   48   18
# 26  2019-03-08    OKC @ LAC  L  241  110  ...   0.654    14    38   52   20
# 27  2019-03-07    OKC @ POR  W  265  129  ...   0.781    16    42   58   14
# 28  2019-03-05    OKC @ MIN  L  239  120  ...   0.581    15    30   45   20
# 29  2019-03-03  OKC vs. MEM  W  242   99  ...   0.727    17    36   53   19
# 30  2019-03-02    OKC @ SAS  L  240  102  ...   0.625    11    34   45   17
# 31  2019-02-28  OKC vs. PHI  L  241  104  ...   0.714     8    36   44   28
# 32  2019-02-26    OKC @ DEN  L  240  112  ...   0.640    14    32   46   31
# 33  2019-02-23  OKC vs. SAC  L  240  116  ...   0.786    16    43   59   17
# 34  2019-02-22  OKC vs. UTA  W  289  148  ...   0.800    11    32   43   29
# ..         ...          ... ..  ...  ...  ...     ...   ...   ...  ...  ...
# 62  2018-12-19    OKC @ SAC  W  241  132  ...   0.630    18    48   66   27
# 63  2018-12-17  OKC vs. CHI  W  242  121  ...   0.818    17    32   49   24
# 64  2018-12-15  OKC vs. LAC  W  239  110  ...   0.708     9    31   40   26
# 65  2018-12-14    OKC @ DEN  L  242   98  ...   0.586    19    24   43   14
# 66  2018-12-12    OKC @ NOP  L  239  114  ...   0.630     9    30   39   23
# 67  2018-12-10  OKC vs. UTA  W  239  122  ...   0.718    12    31   43   25
# 68  2018-12-07    OKC @ CHI  L  240  112  ...   0.667    14    37   51   25
# 69  2018-12-05    OKC @ BKN  W  240  114  ...   0.577    17    43   60   28
# 70  2018-12-03    OKC @ DET  W  241  110  ...   0.850     6    46   52   23
# 71  2018-11-30  OKC vs. ATL  W  241  124  ...   0.933     7    39   46   30
# 72  2018-11-28  OKC vs. CLE  W  240  100  ...   0.800     8    42   50   25
# 73  2018-11-24  OKC vs. DEN  L  240   98  ...   0.652    19    35   54   22
# 74  2018-11-23  OKC vs. CHA  W  240  109  ...   0.667    11    35   46   24
# 75  2018-11-21    OKC @ GSW  W  239  123  ...   0.533    18    43   61   29
# 76  2018-11-19    OKC @ SAC  L  240  113  ...   0.688    13    40   53   22
# 77  2018-11-17    OKC @ PHX  W  240  110  ...   0.844    14    38   52   17
# 78  2018-11-14  OKC vs. NYK  W  240  128  ...   0.833    13    34   47   32
# 79  2018-11-12  OKC vs. PHX  W  241  118  ...   0.950    12    30   42   23
# 80  2018-11-10    OKC @ DAL  L  240   96  ...   0.611    26    27   53   17
# 81  2018-11-08  OKC vs. HOU  W  240   98  ...   0.708    13    39   52   18
# 82  2018-11-07    OKC @ CLE  W  240   95  ...   0.692     7    37   44   10
# 83  2018-11-05  OKC vs. NOP  W  240  122  ...   0.710     9    32   41   26
# 84  2018-11-02    OKC @ WAS  W  238  134  ...   0.808     7    31   38   34
# 85  2018-11-01    OKC @ CHA  W  240  111  ...   0.724    14    35   49   20
# 86  2018-10-30  OKC vs. LAC  W  242  128  ...   0.719     9    32   41   19
# 87  2018-10-28  OKC vs. PHX  W  240  117  ...   0.686     9    34   43   22
# 88  2018-10-25  OKC vs. BOS  L  241   95  ...   0.560    16    41   57   19
# 89  2018-10-21  OKC vs. SAC  L  240  120  ...   0.633    18    33   51   23
# 90  2018-10-19    OKC @ LAC  L  240   92  ...   0.739    15    37   52   18
# 91  2018-10-16    OKC @ GSW  L  240  100  ...   0.649    16    29   45   21
#
#     STL  BLK  TOV  PF  PLUS_MINUS
# 5     4    8   15  22        -9.0
# 6     7    4   14  22       -13.0
# 7     6    5   15  24        12.0
# 8     6    6   16  27       -20.0
# 9    10    4   16  26        -5.0
# 10    7    3   12  20        11.0
# 11    5    2   12  19         1.0
# 12    6    4   13  30         6.0
# 13   10    4   17  24        13.0
# 14   15    7   12  14        16.0
# 15    6    6    8  21        -3.0
# 16    5    5   13  17       -10.0
# 17    7    7    6  14         8.0
# 18    8    4   10  25       -12.0
# 19    9    6   12  21         7.0
# 20    6    2   17  22        -9.0
# 21    4    8   19  17        -9.0
# 22    4    5   16  18       -22.0
# 23   11    5   17  28        -2.0
# 24    9    6   11  20        12.0
# 25    8    5   16  21         9.0
# 26    3    7   11  34        -8.0
# 27    7    5   15  31         8.0
# 28    4    8   12  26       -11.0
# 29   10    5   14  19         4.0
# 30    7    2   13  19       -14.0
# 31    5    3   12  18        -4.0
# 32   10    5   17  34        -9.0
# 33    2    6   14  26        -3.0
# 34   16    5   11  29         1.0
# ..  ...  ...  ...  ..         ...
# 62    8    6   17  24        19.0
# 63   14    2   19  21        25.0
# 64   13    7   11  20         6.0
# 65    9    4   13  17       -11.0
# 66   10    6   18  27        -4.0
# 67   12    2   17  26         9.0
# 68   12    6   22  22        -2.0
# 69    8    6   13  23         2.0
# 70   10    8   17  24        27.0
# 71   12    7   20  24        15.0
# 72    5   11   13  18        17.0
# 73    9    5   10  24        -7.0
# 74    6    2   14  18         5.0
# 75   10    5   10  23        28.0
# 76    8    3   13  22        -4.0
# 77    9    7   18  20        10.0
# 78   11    7   16  21        25.0
# 79   12    6   13  15        17.0
# 80    9    2   16  19       -15.0
# 81   10    4   14  16        18.0
# 82   13    9   12  23         9.0
# 83   15    3   12  23         6.0
# 84   13    5   13  20        23.0
# 85   12    9   10  21         4.0
# 86   16    6   15  35        18.0
# 87   16    3   15  24         7.0
# 88    5    6   16  27        -6.0
# 89   11    9   18  29       -11.0
# 90    5    4   12  29       -16.0
# 91   12    6   14  21        -8.0
#
# [87 rows x 28 columns]

# %%
mask = tmp["SEASON_ID" ]== "22018"
last_season_data = tmp.loc[mask]

# %%
last_season_data.head()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 10     22018  1610612760               OKC  Oklahoma City Thunder  0021801226
# 11     22018  1610612760               OKC  Oklahoma City Thunder  0021801218
# 12     22018  1610612760               OKC  Oklahoma City Thunder  0021801197
# 13     22018  1610612760               OKC  Oklahoma City Thunder  0021801186
# 14     22018  1610612760               OKC  Oklahoma City Thunder  0021801161
#
#      GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 10  2019-04-10    OKC @ MIL  W  240  127  ...   0.615     9    44   53   40
# 11  2019-04-09  OKC vs. HOU  W  240  112  ...   0.800    18    38   56   20
# 12  2019-04-07    OKC @ MIN  W  239  132  ...   0.846    14    32   46   27
# 13  2019-04-05  OKC vs. DET  W  240  123  ...   0.682    21    38   59   30
# 14  2019-04-02  OKC vs. LAL  W  241  119  ...   0.600    17    33   50   33
#
#     STL  BLK  TOV  PF  PLUS_MINUS
# 10    7    3   12  20        11.0
# 11    5    2   12  19         1.0
# 12    6    4   13  30         6.0
# 13   10    4   17  24        13.0
# 14   15    7   12  14        16.0
#
# [5 rows x 28 columns]

# %%
# count data to check NA
total_games= last_season_data["SEASON_ID"].count()
total_games
# look like there is no NA
# Out:
# 82

# %%
# Drop NA, just in case 

last_season_data = last_season_data.dropna()
last_season_data.count()
# Out:
# SEASON_ID            82
# TEAM_ID              82
# TEAM_ABBREVIATION    82
# TEAM_NAME            82
# GAME_ID              82
# GAME_DATE            82
# MATCHUP              82
# WL                   82
# MIN                  82
# PTS                  82
# FGM                  82
# FGA                  82
# FG_PCT               82
# FG3M                 82
# FG3A                 82
# FG3_PCT              82
# FTM                  82
# FTA                  82
# FT_PCT               82
# OREB                 82
# DREB                 82
# REB                  82
# AST                  82
# STL                  82
# BLK                  82
# TOV                  82
# PF                   82
# PLUS_MINUS           82
# dtype: int64

# %%
last_season_data.to_csv(season_out,index=False)

# %%
#split win/loss stat

total_WL_groupby = last_season_data.groupby("WL").count()

total_WL =total_WL_groupby["SEASON_ID"]
total_WL
# Out:
# WL
# L    33
# W    49
# Name: SEASON_ID, dtype: int64
